# %% [markdown]
# # Boltz-2 Python Client - Comprehensive Demo v0.5.0
#
# This notebook demonstrates all key features of boltz2-python-client v0.5.0.
#
# ## Key Features
# - GPU-accelerated MSA Search integration (v2.3.0 API)
# - Enhanced multi-endpoint support
# - Batch MSA processing
# - Paired MSA search and structural template search

# %% [markdown]
# ## 1. Setup
